# %% [markdown]
# ## Scenario One

# %%
v1 = open("test.txt","w")
result = v1.write("first write")
v1.close()

# %%
v2 = open("test.txt", "r")
result = v2.read()
# result = v2.write("ji hello ","w")

# %%
v3 = open("test.txt","w")
result = v3.write("second write after read ")
# v3.close()

# %% [markdown]
# # Scenario Two

# %%
v1 = open("test1.txt","w")
result = v1.write("first write")
v1.close()

# %%
v1 = open("test1.txt", "r")
result = v1.read()
print(v1)
# Out:
# <_io.TextIOWrapper name='test1.txt' mode='r' encoding='cp1252'>

# %%
v1 = open("test1.txt","w")
result = v1.write("second write after read ")

# %% [markdown]
# Testing read and append to understand seek and tell

# %%
v1 = open("test1.txt", "r")
result = v1.read()
result = v1.seek()
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 v1 = open("test1.txt", "r")
#       2 result = v1.read()
# ----> 3 result = v1.seek()
#       4 print(result)
#
# TypeError: seek expected at least 1 argument, got 0
